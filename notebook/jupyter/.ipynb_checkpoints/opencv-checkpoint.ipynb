# %% [markdown]
# ![lina.png](attachment:7f57c94b-6ddc-4409-afdd-19aefc6d2497.png)

# %%
import cv2  # opencv的颜色读取格式为BGR
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

cv2.__version__
# Out:
# '3.4.1'

# %%
# 读取图片
img = cv2.imread("lina.png")
img
# Out:
# array([[[122, 135, 229],
#         [122, 135, 229],
#         [122, 135, 229],
#         ...,
#         [ 96,  96, 196],
#         [ 92,  92, 192],
#         [ 91,  91, 191]],
#
#        [[121, 134, 229],
#         [121, 134, 229],
#         [121, 134, 229],
#         ...,
#         [ 95,  97, 197],
#         [ 92,  93, 193],
#         [ 91,  93, 193]],
#
#        [[114, 134, 227],
#         [114, 134, 227],
#         [114, 134, 227],
#         ...,
#         [ 95,  97, 197],
#         [ 93,  95, 195],
#         [ 93,  94, 194]],
#
#        ...,
#
#        [[ 63,  28,  95],
#         [ 60,  25,  92],
#         [ 60,  24,  91],
#         ...,
#         [ 96,  78, 149],
#         [ 87,  69, 140],
#         [ 80,  60, 132]],
#
#        [[ 65,  30,  97],
#         [ 63,  28,  95],
#         [ 60,  25,  92],
#         ...,
#         [ 89,  71, 142],
#         [ 79,  61, 132],
#         [ 73,  53, 125]],
#
#        [[ 61,  26,  93],
#         [ 63,  28,  95],
#         [ 62,  27,  94],
# ...
